# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir(r'D:\Documents\etudes\epfl\MA1\cours\MachineLearning\Project2\data\twitter_datasets_')

# %%
from glove import Glove
Glove_stan_25 = Glove.load_stanford('glove.twitter.27B.25d.txt')
X_25 = Glove_stan_25.word_vectors

# %%
from sklearn import preprocessing
X_25_scaled = preprocessing.scale(X_25)

# %%
from sklearn.decomposition import PCA
pca_25 = PCA()
pca_25.fit(X_25_scaled)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(pca_25.explained_variance_ratio_*100)
plt.title('explained_variance_ratio_: K=25')
plt.show()

plt.figure()
plt.plot(np.cumsum(pca_25.explained_variance_ratio_*100))
plt.title('cumulative explained_variance_ratio_: K=25')
plt.show()

# %%
from glove import Glove
Glove_stan_100 = Glove.load_stanford('glove.twitter.27B.100d.txt')
X_100 = Glove_stan_100.word_vectors

# %%
from sklearn import preprocessing
X_100_scaled = preprocessing.scale(X_100)

# %%
from sklearn.decomposition import PCA
pca_100 = PCA()
pca_100.fit(X_100_scaled)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(pca_100.explained_variance_ratio_*100)
plt.title('explained_variance_ratio_: K=100')
plt.show()

plt.figure()
plt.plot(np.cumsum(pca_100.explained_variance_ratio_*100))
plt.title('cumulative explained_variance_ratio_: K=100')
plt.show()
