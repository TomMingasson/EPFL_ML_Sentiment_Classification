# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# change path if necessary
import sys
my_path = r'D:\Documents\etudes\epfl\MA1\cours\MachineLearning\Project2'
sys.path.insert(0,my_path + r'/code/COMMON')

# imports
import numpy as np 
import matplotlib.pyplot as plt

# %%
from scipy.signal import convolve

def process_tweet(X_tweet, method):
    
    # mean of the features
    if method is 'mean':
        X_tweet_processed = np.mean(X_tweet, 0)
    
    return X_tweet_processed

# %% [markdown]
# # Load Glove model

# %%
from glove import Corpus
from glove import Glove

# %%
import os
os.chdir(r'D:/Documents/etudes/epfl/MA1/cours/MachineLearning/Project2/data/twitter_datasets_stanford/')

# %%
Glove = Glove.load_stanford('glove.twitter.27B.25d.txt')

# %% [markdown]
# # Load Stop words

# %%
import os
os.chdir(r'D:/Documents/etudes/epfl/MA1/cours/MachineLearning/Project2/data/stop_words/')

# %%
filename_stopwords = 'stop_word_freq_min_100_ratio_marg_0.2.txt'

stop_words = []
with open(filename_stopwords, 'r', encoding='utf-8-sig') as f:
    for line in f:
        stop_words.append(line.lstrip().split()[0])
    del stop_words[-1]
    
print("File :", filename_stopwords)
print("Number of stop words :", len(stop_words))
# Out:
# File : stop_word_freq_min_100_ratio_marg_0.2.txt
# Number of stop words : 1206

# %%
stop_words
# Out:
# ["'",
#  '&',
#  '*',
#  ',',
#  ';',
#  '\\',
#  '_',
#  '__',
#  '`',
#  '{',
#  '}',
#  '~',
#  '<elong>',
#  '<number>d',
#  '<number>day',
#  '<number>days',
#  '<number>ish',
#  '<number>th',
#  '<number>years',
#  '<number>yrs',
#  '=',
#  '->',
#  'a',
#  'aaaw',
#  'aah',
#  'aaron',
#  'abby',
#  'above',
#  'abs',
#  'abt',
#  'account',
#  'accounts',
#  'achieve',
#  'act',
#  'actor',
#  'actually',
#  'adam',
#  'add',
#  'address',
#  'adele',
#  'advance',
#  'after',
#  'again',
#  'ah',
#  'ahh',
#  'aim',
#  'aint',
#  'aj',
#  'alcohol',
#  'alex',
#  'algebra',
#  'alive',
#  'all',
#  'allah',
#  'almost',
#  'already',
#  'although',
#  'am',
#  'amanda',
#  'amsterdam',
#  'and',
#  'andy',
#  'angel',
#  'anger',
#  'anniversary',
#  'announce',
#  'announced',
#  'annoy',
#  'anonymous',
#  'another',
#  'answer',
#  'answered',
#  'any',
#  'anyone',
#  'anything',
#  'apa',
#  'apologies',
#  'apologize',
#  'app',
#  'appearance',
#  'apply',
#  'apprentice',
#  'april',
#  'arena',
#  'argentina',
#  'arguing',
#  'argument',
#  'arrive',
#  'arse',
#  'as',
#  'asap',
#  'ashley',
#  'asked',
#  'asks',
#  'asshole',
#  'at',
#  'atl',
#  'aunt',
#  'aunty',
#  'aus',
#  'austin',
#  'australia',
#  'aw',
#  'awards',
#  'aware',
#  'awh',
#  'awkward',
#  'aww',
#  'awwh',
#  'awwwh',
#  'babies',
#  'baby',
#  'back',
#  'bacon',
#  'badd',
#  'bak',
#  'bake',
#  'baked',
#  'bali',
#  'banana',
#  'barca',
#  'baseball',
#  'basically',
#  'basketball',
#  'bayern',
#  'bbq',
#  'bby',
#  'beach',
#  'beating',
#  'beats',
#  'bebe',
#  'because',
#  'bedroom',
#  'bedtime',
#  'before',
#  'bein',
#  'being',
#  'belfast',
#  'bella',
#  'bend',
#  'beside',
#  'beta',
#  'beth',
#  'bf',
#  'bieber',
#  'big',
#  'biggest',
#  'birmingham',
#  'biscuits',
#  'biting',
#  'blame',
#  'bliss',
#  'blonde',
#  'blown',
#  'bon',
#  'boo',
#  'boob',
#  'boobs',
#  'booth',
#  'born',
#  'bother',
#  'bounce',
#  'bow',
#  'brad',
#  'brave',
#  'break',
#  'breath',
#  'bright',
#  'brighton',
#  'bristol',
#  'bros',
#  'brother',
#  'brothers',
#  'brought',
#  'brownie',
#  'bruh',
#  'bryan',
#  'bs',
#  'bucket',
#  'bucks',
#  'bullshit',
#  'bum',
#  'bump',
#  'bun',
#  'bust',
#  'busy',
#  'button',
#  'buy',
#  'buying',
#  'buzz',
#  'bye',
#  'cafe',
#  'called',
#  'calling',
#  'calls',
#  'calories',
#  'cam',
#  'came',
#  'campus',
#  'candy',
#  'cardio',
#  'care',
#  'carlos',
#  'carnival',
#  'caroline',
#  'caught',
#  'cause',
#  'celebrity',
#  'certain',
#  'chachi',
#  'challenge',
#  'chance',
#  'change',
#  'changed',
#  'chase',
#  'cheat',
#  'checked',
#  'cheek',
#  'cheeks',
#  'cheer',
#  'cheese',
#  'cheesecake',
#  'chelsea',
#  'cher',
#  'cheryl',
#  'chicken',
#  'chin',
#  'chloe',
#  'choices',
#  'choir',
#  'chose',
#  'chris',
#  'christina',
#  'cinema',
#  'ck',
#  'claim',
#  'class',
#  'classes',
#  'cleaned',
#  'closet',
#  'clothes',
#  'clouds',
#  'clubs',
#  'cn',
#  'cod',
#  'coke',
#  'colour',
#  'colours',
#  'come',
#  'compared',
#  'concept',
#  'concert',
#  'concerts',
#  'confirm',
#  'confirmed',
#  'cont',
#  'contact',
#  'continue',
#  'convince',
#  'convinced',
#  'cook',
#  'cookie',
#  'cookies',
#  'cooking',
#  'cops',
#  'cousins',
#  'crack',
#  'craig',
#  'creepy',
#  'crew',
#  'crib',
#  'crowd',
#  'cuddling',
#  'cunt',
#  'curls',
#  'currently',
#  'cus',
#  'cuz',
#  'cyrus',
#  'da',
#  'dah',
#  'dan',
#  'dancers',
#  'dare',
#  'dates',
#  'dating',
#  'daughter',
#  'days',
#  'debate',
#  'decide',
#  'dee',
#  'delicious',
#  'dem',
#  'den',
#  'deny',
#  'describe',
#  'despite',
#  'dessert',
#  'details',
#  'dick',
#  'diff',
#  'difference',
#  'different',
#  'din',
#  'disco',
#  'discount',
#  'district',
#  'ditch',
#  'diva',
#  'diving',
#  'dms',
#  'do',
#  'doll',
#  'dollar',
#  'dollars',
#  'dong',
#  'dose',
#  'doubt',
#  'douche',
#  'dough',
#  'down',
#  'downtown',
#  'drake',
#  'drama',
#  'draw',
#  'drawing',
#  'dreaming',
#  'dreams',
#  'dress',
#  'drink',
#  'drinking',
#  'driving',
#  'drop',
#  'drug',
#  'drunk',
#  'dubai',
#  'dublin',
#  'ducks',
#  'dumb',
#  'easter',
#  'eat',
#  'eating',
#  'eats',
#  'edit',
#  'editing',
#  'effort',
#  'egg',
#  'eggs',
#  'eh',
#  'elf',
#  'emails',
#  'embrace',
#  'emily',
#  'enough',
#  'entered',
#  'entertain',
#  'esp',
#  'especially',
#  'essex',
#  'event',
#  'ever',
#  'every',
#  'everyday',
#  'everything',
#  'everythings',
#  'ex',
#  'example',
#  'excitement',
#  'explain',
#  'eyebrows',
#  'face',
#  'facetime',
#  'factor',
#  'facts',
#  'fag',
#  'faith',
#  'fake',
#  'familiar',
#  'famous',
#  'fancy',
#  'fandom',
#  'far',
#  'faster',
#  'fatty',
#  'feelin',
#  'fest',
#  'fifa',
#  'fight',
#  'fights',
#  'fill',
#  'find',
#  'finished',
#  'finishing',
#  'first',
#  'flags',
#  'flight',
#  'flow',
#  'flowers',
#  'fly',
#  'flyers',
#  'for',
#  'found',
#  'france',
#  'freakin',
#  'free',
#  'fresh',
#  'freshman',
#  'fri',
#  'friendly',
#  'friendship',
#  'frm',
#  'fuck',
#  'fucker',
#  'fuckin',
#  'gaga',
#  'gain',
#  'gained',
#  'gal',
#  'gave',
#  'gay',
#  'genius',
#  'get',
#  'gets',
#  'getting',
#  'gf',
#  'ghetto',
#  'gift',
#  'gig',
#  'girlfriends',
#  'given',
#  'glasgow',
#  'glee',
#  'go',
#  'going',
#  'gomez',
#  'gona',
#  'gonna',
#  'goods',
#  'goose',
#  'gossip',
#  'got',
#  'grades',
#  'grandparents',
#  'grass',
#  'greg',
#  'grown',
#  'guess',
#  'guest',
#  'gunna',
#  'gusto',
#  'habit',
#  'hair',
#  'haircut',
#  'halfway',
#  'hands',
#  'hang',
#  'hangout',
#  'happens',
#  'hardcore',
#  'have',
#  'having',
#  'he',
#  'hearing',
#  'heaven',
#  'heck',
#  'heels',
#  'hell',
#  'help',
#  'helps',
#  'her',
#  'here',
#  'hers',
#  'hide',
#  'higher',
#  'highschool',
#  'him',
#  'hips',
#  'his',
#  'hit',
#  'hitler',
#  'hold',
#  'holding',
#  'holland',
#  'hollie',
#  'hologram',
#  'honestly',
#  'honor',
#  'hook',
#  'hop',
#  'hoping',
#  'horny',
#  'hotel',
#  'hottest',
#  'how',
#  'hunger',
#  'hurry',
#  'hv',
#  'hve',
#  'hyper',
#  'i',
#  'ian',
#  'ice',
#  'idea',
#  'ideas',
#  'idiots',
#  'idol',
#  'ik',
#  'iknow',
#  'il',
#  'im',
#  'imagine',
#  'immediately',
#  'important',
#  'ina',
#  'incase',
#  'incredible',
#  'indonesia',
#  'ini',
#  'init',
#  'inn',
#  'insane',
#  'insecure',
#  'inspirational',
#  'instantly',
#  'instead',
#  'internship',
#  'interviews',
#  'introduce',
#  'invented',
#  'invite',
#  'invited',
#  'irish',
#  'is',
#  'it',
#  'italy',
#  'its',
#  'ja',
#  'jacob',
#  'jade',
#  'jam',
#  'jamie',
#  'jasmine',
#  'jay',
#  'jd',
#  'je',
#  'jenny',
#  'jerry',
#  'jessie',
#  'jesus',
#  'jo',
#  'job',
#  'joel',
#  'joey',
#  'joke',
#  'josh',
#  'joy',
#  'jst',
#  'juan',
#  'juice',
#  'julie',
#  'july',
#  'jump',
#  'just',
#  'justin',
#  'k',
#  'kaka',
#  'kan',
#  'kasi',
#  'kat',
#  'katie',
#  'keen',
#  'keeper',
#  'keith',
#  'kevin',
#  'kicks',
#  'kinda',
#  'kinds',
#  'km',
#  'knew',
#  'knicks',
#  'knw',
#  'ko',
#  'kyle',
#  'lagi',
#  'laid',
#  'lame',
#  'laughed',
#  'launch',
#  'laura',
#  'lauren',
#  'lay',
#  'laying',
#  'lean',
#  'learn',
#  'legit',
#  'leo',
#  'lesbian',
#  'less',
#  'lesson',
#  'letter',
#  'liar',
#  'lie',
#  'life',
#  'lifes',
#  'like',
#  'likely',
#  'lipstick',
#  'lisa',
#  'lit',
#  'little',
#  'liz',
#  'll',
#  'lloyd',
#  'local',
#  'looked',
#  'lool',
#  'looong',
#  'lord',
#  'loser',
#  'lovers',
#  'lush',
#  'lyk',
#  'made',
#  'main',
#  'makes',
#  'making',
#  'malaysia',
#  'mane',
#  'manila',
#  'mans',
#  'many',
#  'marathon',
#  'maria',
#  'maroon',
#  'massive',
#  'match',
#  'matching',
#  'mates',
#  'matt',
#  'mau',
#  'mcdonalds',
#  'me',
#  'mean',
#  'meaning',
#  'meg',
#  'megan',
#  'melbourne',
#  'melt',
#  'member',
#  'members',
#  'ment',
#  'mentions',
#  'menu',
#  'mess',
#  'messages',
#  'messing',
#  'mexican',
#  'michelle',
#  'mighty',
#  'mii',
#  'mile',
#  'min',
#  'mine',
#  'mins',
#  'minus',
#  'mixtape',
#  'mj',
#  'mo',
#  'mom',
#  'moments',
#  'moms',
#  'month',
#  'mood',
#  'more',
#  'morn',
#  'mostly',
#  'mother',
#  'mothers',
#  'motivated',
#  'mouth',
#  'movie',
#  'mr',
#  'mrs',
#  'msg',
#  'mt',
#  'mtv',
#  'much',
#  'muffin',
#  'muscles',
#  'music',
#  'my',
#  'myself',
#  'n',
#  'na',
#  'naa',
#  'nails',
#  'named',
#  'nap',
#  'naps',
#  'narnia',
#  'nasty',
#  'necessary',
#  'needing',
#  'needs',
#  'negative',
#  'neighbor',
#  'neighbors',
#  'nerves',
#  'netflix',
#  'nevermind',
#  'new',
#  'newcastle',
#  'ni',
#  'nick',
#  'nikki',
#  'nina',
#  'ninja',
#  'nipples',
#  'noon',
#  'nope',
#  'normal',
#  'normally',
#  'norway',
#  'note',
#  'nothing',
#  'now',
#  'noww',
#  'nutella',
#  'nvm',
#  'nw',
#  'nxt',
#  'nyc',
#  'o_o',
#  'obsession',
#  "o'clock",
#  'odd',
#  'off',
#  'offended',
#  'officially',
#  'often',
#  'ohwell',
#  'oi',
#  'older',
#  'olivia',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'onto',
#  'oo',
#  'opportunity',
#  'or',
#  'orders',
#  'oreo',
#  'other',
#  'otherwise',
#  'out',
#  'outta',
#  'ova',
#  'own',
#  'packing',
#  'paid',
#  'pants',
#  'papa',
#  'park',
#  'parking',
#  'parties',
#  'partner',
#  'pass',
#  'pay',
#  'payday',
#  'paying',
#  'peek',
#  'pens',
#  'people',
#  'peoples',
#  'perfect',
#  'perfection',
#  'perform',
#  'performances',
#  'perfume',
#  'period',
#  'pete',
#  'phil',
#  'phillip',
#  'philly',
#  'photo',
#  'picked',
#  'pictures',
#  'pie',
#  'pierced',
#  'pinky',
#  'pint',
#  'piss',
#  'pj',
#  'place',
#  'planning',
#  'plans',
#  'play',
#  'played',
#  'playing',
#  'playlist',
#  'pls',
#  'pm',
#  'poem',
#  'pointless',
#  'points',
#  'pooh',
#  'pool',
#  'pop',
#  'popcorn',
#  'popped',
#  'popping',
#  'pops',
#  'pork',
#  'porn',
#  'pose',
#  'possible',
#  'post',
#  'posters',
#  'posts',
#  'potatoes',
#  'pour',
#  'pow',
#  'praise',
#  'pray',
#  'praying',
#  'precious',
#  'premiere',
#  'prepare',
#  'prepared',
#  'preparing',
#  'presence',
#  'pretend',
#  'princess',
#  'probably',
#  'profile',
#  'progress',
#  'prolly',
#  'promised',
#  'promises',
#  'promo',
#  'pub',
#  'pull',
#  'pulling',
#  'pun',
#  'punch',
#  'push',
#  'pushing',
#  'qt',
#  'que',
#  'queen',
#  'questions',
#  'quiet',
#  'quit',
#  'quiz',
#  'rachel',
#  'rae',
#  'randomly',
#  'rap',
#  'reached',
#  'reaching',
#  'reading',
#  'reads',
#  'real',
#  'recipe',
#  'reece',
#  'refreshing',
#  'register',
#  'regret',
#  'relay',
#  'remain',
#  'reminds',
#  'replace',
#  'replay',
#  'replied',
#  'reserve',
#  'resist',
#  'respond',
#  'rest',
#  'restaurant',
#  'result',
#  'retarded',
#  'reunion',
#  'revenge',
#  'ricky',
#  'ride',
#  'rides',
#  'riding',
#  'right',
#  'rihanna',
#  'rita',
#  'rite',
#  'rob',
#  'role',
#  'roll',
#  'romantic',
#  'route',
#  'routine',
#  'row',
#  'rugby',
#  'rule',
#  'run',
#  'runs',
#  'rush',
#  'ryan',
#  'ryt',
#  's',
#  'safely',
#  'said',
#  'salad',
#  'salon',
#  'sam',
#  'same',
#  'sana',
#  'sandwich',
#  'sandwiches',
#  'sara',
#  'sarah',
#  'saturday',
#  'saving',
#  'saw',
#  'says',
#  'score',
#  'scream',
#  'screamed',
#  'screaming',
#  'sean',
#  'seats',
#  'seconds',
#  'seein',
#  'seeing',
#  'sees',
#  'sending',
#  'sends',
#  'served',
#  'settle',
#  'sexual',
#  'sh',
#  'shades',
#  'shared',
#  'sheffield',
#  'shinee',
#  'ship',
#  'shirt',
#  'shit',
#  'shits',
#  'sho',
#  'shop',
#  'shops',
#  'shorts',
#  'shot',
#  'shots',
#  'shoulders',
#  'shouting',
#  'showers',
#  'shrimp',
#  'shud',
#  'shut',
#  'shyt',
#  'si',
#  'side',
#  'sign',
#  'silence',
#  'singers',
#  'sisters',
#  'sit',
#  'site',
#  'skool',
#  'sky',
#  'skype',
#  'slap',
#  'sleeps',
#  'slick',
#  'smart',
#  'smarter',
#  'smells',
#  'smoked',
#  'snacks',
#  'so',
#  'soccer',
#  'somebody',
#  'somehow',
#  'someones',
#  'something',
#  'sometimes',
#  'somewhere',
#  'son',
#  'soo',
#  'sophie',
#  'sound',
#  'sounded',
#  'sour',
#  'spaghetti',
#  'spamming',
#  'speaking',
#  'special',
#  'spelling',
#  'spend',
#  'spree',
#  ...]

# %%
print("happy" in stop_words)
print("another" in stop_words)
# Out:
# False
# True

# %% [markdown]
# # Build tweet vectors

# %%
import os
os.chdir(r'D:\Documents\etudes\epfl\MA1\cours\MachineLearning\Project2\data\twitter_datasets_epfl\short')

# %%
# method to build tweet vector
method = "mean"

# %%
# build positive tweet feature set
X_pos = []

with open('train_pos_processed.txt') as f:
    for line in f:
        tweet = line.lstrip().split()
        X_tweet = []
        for word in tweet:
            if word in Glove.dictionary and not word in stop_words:
                word_vector = Glove.word_vectors[Glove.dictionary.get(word)]
                X_tweet.append(word_vector)
                
        if X_tweet:
            X_tweet_processed = process_tweet(X_tweet, method)
            X_pos.append(X_tweet_processed)
        
X_pos = np.array(X_pos)

# %%
# build negative tweet feature set
X_neg = []

with open('train_neg_processed.txt') as f:
    for line in f:
        tweet = line.lstrip().split()
        X_tweet = []
        for word in tweet:
            if word in Glove.dictionary and not word in stop_words:
                word_vector = Glove.word_vectors[Glove.dictionary.get(word)]
                X_tweet.append(word_vector)
                
        if X_tweet:
            X_tweet_processed = process_tweet(X_tweet, method)
            X_neg.append(X_tweet_processed)
        
X_neg = np.array(X_neg)

# %%
y_pos = np.ones(X_pos.shape[0])
y_neg = -np.ones(X_neg.shape[0])

# %%
print(X_pos.shape)
print(X_neg.shape)
# Out:
# (90185, 25)
# (91051, 25)

# %%
N_samples_train = 100 

# cut samples
X_pos_cut = X_pos[:N_samples_train,:]
X_neg_cut = X_neg[:N_samples_train,:]

# cut targets
y_pos_cut = y_pos[:N_samples_train]
y_neg_cut = y_neg[:N_samples_train]

# %%
X_pos_neg = np.concatenate([X_pos_cut, X_neg_cut])
y_pos_neg = np.concatenate([y_pos_cut, y_neg_cut])

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_pos_neg)
X_pos_neg_scaled = scaler.transform(X_pos_neg)

# %% [markdown]
# # Hyperparameter optimization KNN

# %%
from __future__ import print_function

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.neighbors import NearestNeighbors

# data
X = X_pos_neg_scaled
y = y_pos_neg

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# range for hyperparameters
K_range = range(10)

# Set the parameters by cross-validation
tuned_parameters = [{'n_neighbors': K_range}]
                    
# define grid search CV
clf = GridSearchCV(NearestNeighbors(), tuned_parameters, cv=5, scoring= 'accuracy')

# fit for every parameters combinations in grid search CV
clf.fit(X_train, y_train)
# Out:
# Automatically created module for IPython interactive environment
# Best parameters set found on development set:
#
# {'C': 4.6415888336127775, 'gamma': 0.10000000000000001}
#
# Grid scores on development set:
#
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 2.1544346900318822e-08}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 4.6415888336127725e-07}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 1.0000000000000001e-05}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 0.00021544346900318823}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 0.0046415888336127729}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 0.10000000000000001}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 2.1544346900318822e-08}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 4.6415888336127725e-07}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 1.0000000000000001e-05}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 0.00021544346900318823}
# 0.520 (+/-0.034) for {'C': 0.21544346900318834, 'gamma': 0.0046415888336127729}
# 0.533 (+/-0.043) for {'C': 0.21544346900318834, 'gamma': 0.10000000000000001}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 2.1544346900318822e-08}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 4.6415888336127725e-07}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 1.0000000000000001e-05}
# 0.580 (+/-0.052) for {'C': 4.6415888336127775, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.072) for {'C': 4.6415888336127775, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 4.6415888336127775, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 4.6415888336127775, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 2.1544346900318822e-08}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 4.6415888336127725e-07}
# 0.580 (+/-0.052) for {'C': 100.0, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.083) for {'C': 100.0, 'gamma': 0.00021544346900318823}
# 0.647 (+/-0.148) for {'C': 100.0, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 100.0, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 100.0, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 2154.4346900318824, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 2154.4346900318824, 'gamma': 2.1544346900318822e-08}
# 0.580 (+/-0.052) for {'C': 2154.4346900318824, 'gamma': 4.6415888336127725e-07}
# 0.627 (+/-0.076) for {'C': 2154.4346900318824, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.077) for {'C': 2154.4346900318824, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 2154.4346900318824, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 2154.4346900318824, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 2154.4346900318824, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 2154.4346900318824, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 2154.4346900318824, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 46415.888336127726, 'gamma': 1.0000000000000001e-09}
# 0.580 (+/-0.052) for {'C': 46415.888336127726, 'gamma': 2.1544346900318822e-08}
# 0.627 (+/-0.076) for {'C': 46415.888336127726, 'gamma': 4.6415888336127725e-07}
# 0.620 (+/-0.040) for {'C': 46415.888336127726, 'gamma': 1.0000000000000001e-05}
# 0.660 (+/-0.163) for {'C': 46415.888336127726, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 46415.888336127726, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 46415.888336127726, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 46415.888336127726, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 46415.888336127726, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 46415.888336127726, 'gamma': 1000.0}
# 0.613 (+/-0.048) for {'C': 1000000.0, 'gamma': 1.0000000000000001e-09}
# 0.633 (+/-0.128) for {'C': 1000000.0, 'gamma': 2.1544346900318822e-08}
# 0.620 (+/-0.071) for {'C': 1000000.0, 'gamma': 4.6415888336127725e-07}
# 0.613 (+/-0.098) for {'C': 1000000.0, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.193) for {'C': 1000000.0, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 1000000.0, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 1000000.0, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 1000000.0, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 1000000.0, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 1000000.0, 'gamma': 1000.0}
# 0.613 (+/-0.052) for {'C': 21544346.900318779, 'gamma': 1.0000000000000001e-09}
# 0.613 (+/-0.100) for {'C': 21544346.900318779, 'gamma': 2.1544346900318822e-08}
# 0.613 (+/-0.095) for {'C': 21544346.900318779, 'gamma': 4.6415888336127725e-07}
# 0.620 (+/-0.148) for {'C': 21544346.900318779, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.193) for {'C': 21544346.900318779, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 21544346.900318779, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 21544346.900318779, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 21544346.900318779, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 21544346.900318779, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 21544346.900318779, 'gamma': 1000.0}
# 0.580 (+/-0.101) for {'C': 464158883.36127728, 'gamma': 1.0000000000000001e-09}
# 0.613 (+/-0.121) for {'C': 464158883.36127728, 'gamma': 2.1544346900318822e-08}
# 0.620 (+/-0.106) for {'C': 464158883.36127728, 'gamma': 4.6415888336127725e-07}
# 0.607 (+/-0.059) for {'C': 464158883.36127728, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.193) for {'C': 464158883.36127728, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 464158883.36127728, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 464158883.36127728, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 464158883.36127728, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 464158883.36127728, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 464158883.36127728, 'gamma': 1000.0}
# 0.567 (+/-0.111) for {'C': 10000000000.0, 'gamma': 1.0000000000000001e-09}
# 0.647 (+/-0.126) for {'C': 10000000000.0, 'gamma': 2.1544346900318822e-08}
# 0.627 (+/-0.049) for {'C': 10000000000.0, 'gamma': 4.6415888336127725e-07}
# 0.587 (+/-0.061) for {'C': 10000000000.0, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.193) for {'C': 10000000000.0, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 10000000000.0, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 10000000000.0, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 10000000000.0, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 10000000000.0, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 10000000000.0, 'gamma': 1000.0}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#        -1.0       0.60      0.44      0.51        27
#         1.0       0.50      0.65      0.57        23
#
# avg / total       0.55      0.54      0.54        50

# %%
print("Best parameters set found on development set:")
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()

means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r"
          % (mean, std * 2, params))
    
print()
print("Detailed classification report:")
print()
print("The model is trained on the full development set.")
print("The scores are computed on the full evaluation set.")
print()
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))
print()
# Out:
# Best parameters set found on development set:
#
# {'C': 4.6415888336127775, 'gamma': 0.10000000000000001}
#
# Grid scores on development set:
#
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 2.1544346900318822e-08}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 4.6415888336127725e-07}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 1.0000000000000001e-05}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 0.00021544346900318823}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 0.0046415888336127729}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 0.10000000000000001}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 0.01, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 2.1544346900318822e-08}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 4.6415888336127725e-07}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 1.0000000000000001e-05}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 0.00021544346900318823}
# 0.520 (+/-0.034) for {'C': 0.21544346900318834, 'gamma': 0.0046415888336127729}
# 0.533 (+/-0.043) for {'C': 0.21544346900318834, 'gamma': 0.10000000000000001}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 0.21544346900318834, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 2.1544346900318822e-08}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 4.6415888336127725e-07}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 1.0000000000000001e-05}
# 0.580 (+/-0.052) for {'C': 4.6415888336127775, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.072) for {'C': 4.6415888336127775, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 4.6415888336127775, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 4.6415888336127775, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 4.6415888336127775, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 2.1544346900318822e-08}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 4.6415888336127725e-07}
# 0.580 (+/-0.052) for {'C': 100.0, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.083) for {'C': 100.0, 'gamma': 0.00021544346900318823}
# 0.647 (+/-0.148) for {'C': 100.0, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 100.0, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 100.0, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 100.0, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 2154.4346900318824, 'gamma': 1.0000000000000001e-09}
# 0.513 (+/-0.013) for {'C': 2154.4346900318824, 'gamma': 2.1544346900318822e-08}
# 0.580 (+/-0.052) for {'C': 2154.4346900318824, 'gamma': 4.6415888336127725e-07}
# 0.627 (+/-0.076) for {'C': 2154.4346900318824, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.077) for {'C': 2154.4346900318824, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 2154.4346900318824, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 2154.4346900318824, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 2154.4346900318824, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 2154.4346900318824, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 2154.4346900318824, 'gamma': 1000.0}
# 0.513 (+/-0.013) for {'C': 46415.888336127726, 'gamma': 1.0000000000000001e-09}
# 0.580 (+/-0.052) for {'C': 46415.888336127726, 'gamma': 2.1544346900318822e-08}
# 0.627 (+/-0.076) for {'C': 46415.888336127726, 'gamma': 4.6415888336127725e-07}
# 0.620 (+/-0.040) for {'C': 46415.888336127726, 'gamma': 1.0000000000000001e-05}
# 0.660 (+/-0.163) for {'C': 46415.888336127726, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 46415.888336127726, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 46415.888336127726, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 46415.888336127726, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 46415.888336127726, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 46415.888336127726, 'gamma': 1000.0}
# 0.613 (+/-0.048) for {'C': 1000000.0, 'gamma': 1.0000000000000001e-09}
# 0.633 (+/-0.128) for {'C': 1000000.0, 'gamma': 2.1544346900318822e-08}
# 0.620 (+/-0.071) for {'C': 1000000.0, 'gamma': 4.6415888336127725e-07}
# 0.613 (+/-0.098) for {'C': 1000000.0, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.193) for {'C': 1000000.0, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 1000000.0, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 1000000.0, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 1000000.0, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 1000000.0, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 1000000.0, 'gamma': 1000.0}
# 0.613 (+/-0.052) for {'C': 21544346.900318779, 'gamma': 1.0000000000000001e-09}
# 0.613 (+/-0.100) for {'C': 21544346.900318779, 'gamma': 2.1544346900318822e-08}
# 0.613 (+/-0.095) for {'C': 21544346.900318779, 'gamma': 4.6415888336127725e-07}
# 0.620 (+/-0.148) for {'C': 21544346.900318779, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.193) for {'C': 21544346.900318779, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 21544346.900318779, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 21544346.900318779, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 21544346.900318779, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 21544346.900318779, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 21544346.900318779, 'gamma': 1000.0}
# 0.580 (+/-0.101) for {'C': 464158883.36127728, 'gamma': 1.0000000000000001e-09}
# 0.613 (+/-0.121) for {'C': 464158883.36127728, 'gamma': 2.1544346900318822e-08}
# 0.620 (+/-0.106) for {'C': 464158883.36127728, 'gamma': 4.6415888336127725e-07}
# 0.607 (+/-0.059) for {'C': 464158883.36127728, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.193) for {'C': 464158883.36127728, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 464158883.36127728, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 464158883.36127728, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 464158883.36127728, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 464158883.36127728, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 464158883.36127728, 'gamma': 1000.0}
# 0.567 (+/-0.111) for {'C': 10000000000.0, 'gamma': 1.0000000000000001e-09}
# 0.647 (+/-0.126) for {'C': 10000000000.0, 'gamma': 2.1544346900318822e-08}
# 0.627 (+/-0.049) for {'C': 10000000000.0, 'gamma': 4.6415888336127725e-07}
# 0.587 (+/-0.061) for {'C': 10000000000.0, 'gamma': 1.0000000000000001e-05}
# 0.620 (+/-0.193) for {'C': 10000000000.0, 'gamma': 0.00021544346900318823}
# 0.640 (+/-0.222) for {'C': 10000000000.0, 'gamma': 0.0046415888336127729}
# 0.693 (+/-0.118) for {'C': 10000000000.0, 'gamma': 0.10000000000000001}
# 0.527 (+/-0.040) for {'C': 10000000000.0, 'gamma': 2.154434690031878}
# 0.513 (+/-0.013) for {'C': 10000000000.0, 'gamma': 46.415888336127729}
# 0.513 (+/-0.013) for {'C': 10000000000.0, 'gamma': 1000.0}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#        -1.0       0.60      0.44      0.51        27
#         1.0       0.50      0.65      0.57        23
#
# avg / total       0.55      0.54      0.54        50

# %%
from matplotlib.colors import Normalize

# Utility function to move the midpoint of a colormap to be around
# the values of interest.

class MidpointNormalize(Normalize):

    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))
   
scores = clf.cv_results_['mean_test_score'].reshape(len(C_range), len(gamma_range))

plt.figure(figsize=(8, 6))
plt.subplots_adjust(left=.2, right=0.95, bottom=0.15, top=0.95)
plt.imshow(scores, interpolation='nearest', cmap=plt.cm.hot, norm=MidpointNormalize(vmin=0.2, midpoint=0.92))
plt.xlabel('gamma')
plt.ylabel('C')
plt.colorbar()
plt.xticks(np.arange(len(gamma_range)), gamma_range, rotation=45)
plt.yticks(np.arange(len(C_range)), C_range)
plt.title('Validation accuracy')
plt.show()

# %% [markdown]
# # Predict

# %%
import os
os.chdir(r'D:\Documents\etudes\epfl\MA1\cours\MachineLearning\Project2\data\twitter_datasets_epfl\short')

# %%
X_test = []

with open('test_data_no_id_processed.txt') as f:
    
    for line in f:
        
        tweet = line.lstrip().split()
        X_tweet = []
        
        for word in tweet:
            
            if word in Glove.dictionary and not word in stop_words:
                
                word_vector = Glove.word_vectors[Glove.dictionary.get(word)]
                X_tweet.append(word_vector)
                
        if X_tweet:
            
            X_tweet_processed = process_tweet(X_tweet, method)
            X_test.append(X_tweet_processed)
        
X_test = np.array(X_test) 
print(X_test.shape)

# %%
# standarization
X_test_scaled = scaler.transform(X_test)

# %%
# predict
y_pred = clf.predict(X_test)

# %% [markdown]
# # Submission

# %%
import os
os.chdir(r'D:/Documents/etudes/epfl/MA1/cours/MachineLearning/Project2/data/submissions/')

# %%
from create_csv_submission import create_csv_submission
import time
import datetime
i = datetime.datetime.now()

name = "sub_" + time.strftime("%d_%m_%Y") +  "_%sh_%smin" % (i.hour, i.minute)
#name = "vrf"
ids_test = range(1, X_test.shape[0]+1)
create_csv_submission(ids_test, y_pred, name)
